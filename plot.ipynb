# %%
import pandas as pd
# import numpy as np

# %%
df=pd.read_csv('D:\Data Base\CSV file\\cars_NPTEL.csv')
df.tail()
# Out:
#             dateCrawled                                               name  \
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# 49996     private   request      0     test            bus
# 49997     private   request  19999  control            NaN
# 49998     private   request      0     test          coupe
# 49999  commercial     offer    100  control  station wagon
# 50000  commercial     offer   1100     test      small car
#
#        yearOfRegistration gearbox  powerPS        model  kilometer  \
# 49996                2005     NaN        0  transporter     150000
# ...

# %%
df.shape
# Out:
# (50001, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50001 non-null  object
#  1   name                 50001 non-null  object
#  2   seller               50001 non-null  object
#  3   offerType            50001 non-null  object
#  4   price                50001 non-null  int64
#  5   abtest               50001 non-null  object
#  6   vehicleType          44813 non-null  object
#  7   yearOfRegistration   50001 non-null  int64
#  8   gearbox              47177 non-null  object
#  9   powerPS              50001 non-null  int64
#  10  model                47243 non-null  object
#  11  kilometer            50001 non-null  int64
#  12  monthOfRegistration  50001 non-null  int64
#  13  fuelType             45498 non-null  object
#  14  brand                50001 non-null  object
# ...

# %%
#check missing values
df.isnull().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5188
# yearOfRegistration        0
# gearbox                2824
# powerPS                   0
# model                  2758
# kilometer                 0
# monthOfRegistration       0
# fuelType               4503
# brand                     0
# notRepairedDamage      9716
# dateCreated               0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
df.shape
# Out:
# (50001, 19)

# %%
#it will drop all null values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (35107, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35107 entries, 1 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          35107 non-null  object
#  1   name                 35107 non-null  object
#  2   seller               35107 non-null  object
#  3   offerType            35107 non-null  object
#  4   price                35107 non-null  int64
#  5   abtest               35107 non-null  object
#  6   vehicleType          35107 non-null  object
#  7   yearOfRegistration   35107 non-null  int64
#  8   gearbox              35107 non-null  object
#  9   powerPS              35107 non-null  int64
#  10  model                35107 non-null  object
#  11  kilometer            35107 non-null  int64
#  12  monthOfRegistration  35107 non-null  int64
#  13  fuelType             35107 non-null  object
#  14  brand                35107 non-null  object
# ...

# %% [markdown]
# # visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df.head(1000)
df
# Out:
#            dateCrawled                                               name  \
# 1        7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 3     19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4     16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# 5       2/4/2016 12:51           VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 7     24/03/2016 15:52                        Mercedes_Benz_CLK_Coupe_200
# ...                ...                                                ...
# 1429    8/3/2016 16:47                          opel_kadett_30000_km_erst
# 1431    2/4/2016 21:51      einen_gepflegten_Mazda_CX9_Benzin/Autogas_LPG
# 1433  13/03/2016 18:52                            Volkswagen_up!_move_up!
# 1435   11/3/2016 22:50  Volkswagen_2.0TSi_SCHECKHEFTGEPFLEGT_INSPEKTIO...
# 1436  17/03/2016 10:58                      Opel_Astra_Twin_Top_1.8_Cosmo
#
#        seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
# fig=plt.figure(figsize=(10,12))
x=df['seller']  #object
y=df['kilometer']  #integer


plt.bar(x,y,color="maroon",width=0.4)

# plt.xlabel("Seller")
# plt.ylabel("Kilometer")
# plt.title('Seller & kilometer')
plt.savefig('sample.png',transparent=True)
plt.show()

# %%
plt.bar(df['gearbox'],df['powerPS'],color="g")

plt.xlabel("Gear")
plt.show()

# %%
#line plot

# %%
plt.plot(df['powerPS'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1436
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          1000 non-null   object
#  1   name                 1000 non-null   object
#  2   seller               1000 non-null   object
#  3   offerType            1000 non-null   object
#  4   price                1000 non-null   int64
#  5   abtest               1000 non-null   object
#  6   vehicleType          1000 non-null   object
#  7   yearOfRegistration   1000 non-null   int64
#  8   gearbox              1000 non-null   object
#  9   powerPS              1000 non-null   int64
#  10  model                1000 non-null   object
#  11  kilometer            1000 non-null   int64
#  12  monthOfRegistration  1000 non-null   int64
#  13  fuelType             1000 non-null   object
#  14  brand                1000 non-null   object
# ...

# %%
#Scatter
plt.scatter(df['powerPS'],df['price'])
plt.show()

# %%
#histogram

plt.hist(df['kilometer'])
plt.show()

# %%
#boxplot

sns.boxplot(x=df['seller'],y=df['kilometer'],hue=df['fuelType'])
plt.show()

# %%
df['kilometer'].describe()
# Out:
# count      1000.000000
# mean     124305.000000
# std       39236.226328
# min        5000.000000
# 25%      100000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: kilometer, dtype: float64

# %%
#pair plot

sns.pairplot(df)
